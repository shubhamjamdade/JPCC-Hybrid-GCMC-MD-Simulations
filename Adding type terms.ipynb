# %%
import os, shutil, math

# %%
f = open(path+'/'+file,'r')
lines=f.readlines()

for line in lines:
    row=line.split()
    if not line.strip():
         continue
            
    if not len(row) == 6 and row[3] == '#':
        if not len(row) == 10 and row[3] == 'fourier':
            if not len(row) == 10 and row[3] == 'cosine/periodic':
                if not len(row) == 9 and row[4] == '#':
                    if not len(row) == 12 and row[7] == '#':
                        if 
                        with open(path_cif, 'a') as file:
                            file.write(str(line))

    if len(row) == 6 and row[3] == '#':

        basic_line =  os.linesep + str(row[0]) + os.linesep + str(row[1]) + os.linesep + str(row[2]) + os.linesep + str(row[3]) + os.linesep + str(row[4]) + os.linesep + str(row[5]) 

        with open(path_cif, 'a') as file:

            file.write(str(basic_line))

       break
