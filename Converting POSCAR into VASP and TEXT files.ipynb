# %%
import os
from pathlib import Path

for i in range(1, 50):
    
    folder = r'/Users/shubhamjamdade/Desktop/POSCAR_VASP/'+str(i)+'/'

    entries = os.listdir(folder) 
    entries.sort() #alphabetical sort
    for entry in entries:
        p = Path(str(folder)+str(entry))
        p.rename(p.with_suffix('.vasp'))

# %%
import os
from pathlib import Path

for i in range(1, 50):
    
    folder = r'/Users/shubhamjamdade/Desktop/POSCAR_TEXT/'+str(i)+'/'

    entries = os.listdir(folder) 
    entries.sort() #alphabetical sort
    for entry in entries:
        p = Path(str(folder)+str(entry))
        p.rename(p.with_suffix('.vasp'))
